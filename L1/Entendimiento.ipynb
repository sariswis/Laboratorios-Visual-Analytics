# %% [markdown]
# ## Entendimiento del archivo de Siniestros Viales
#
# **Realizado por:** Sara Sofía Cárdenas Rodríguez y Jhoan Sebastián Sánchez Suárez
#
# **Archivo:** `historico_siniestros_bogota_2017.csv`

# %% [markdown]
# ## 0. Inicialización

# %% [markdown]
# Importaciones

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tabulate import tabulate

# %% [markdown]
# Visualización de tablas y gráficas

# %%
sns.set_style("darkgrid")

def print_table(df):
    print(tabulate(df, headers='keys', tablefmt='simple_outline'))

# %% [markdown]
# Lectura del archivo

# %%
df =  pd.read_csv("historico_siniestros_bogota_2017.csv")
df = df.rename(columns={'Unnamed: 0': 'ID'}) # Renombrar primera columna
df.head()
# Out:
#        ID  OBJECTID   FORMULARIO  CODIGO_ACCIDENTE  FECHA_OCURRENCIA_ACC  \
# 0  840142    451106   A001393604        10565887.0         1647406800000
# 1  747565    728008  AA001057402        11115230.0         1571374800000
# 2  744198    372498   A001055948        10499024.0         1570165200000
# 3  570467    631431  AA000552205        11001813.0         1486530000000
# 4  590737    303501   A000607860         4483415.0         1496120400000
#
#   HORA_OCURRENCIA_ACC  ANO_OCURRENCIA_ACC MES_OCURRENCIA_ACC  \
# 0            06:34:00              2022.0              MARZO
# 1            19:30:00              2019.0            OCTUBRE
# 2            09:15:00              2019.0            OCTUBRE
# 3            10:00:00              2017.0            FEBRERO
# 4            17:50:00              2017.0               MAYO
#
#   DIA_OCURRENCIA_ACC                    DIRECCION     GRAVEDAD  CLASE_ACC  \
# 0          MIERCOLES                  KR 86 72 02   SOLO DANOS     CHOQUE
# 1            VIERNES                 KR 50-CL 3 2  CON HERIDOS     CHOQUE
# 2            VIERNES                KR 7-CL 71 21   SOLO DANOS     CHOQUE
# 3          MIERCOLES  AV AVENIDA BOYACA-CL 127 02   SOLO DANOS     CHOQUE
# 4             MARTES           KR 79F-CL 47B S 02  CON HERIDOS  ATROPELLO
#
#        LOCALIDAD  MUNICIPIO  FECHA_HORA_ACC   LATITUD   LONGITUD         CIV  \
# 0       ENGATIVA  BOGOTA DC   1647430440000  4.696000 -74.106000  10006480.0
# 1  PUENTE ARANDA  BOGOTA DC   1571445000000  4.615541 -74.114489  16004606.0
# 2      CHAPINERO  BOGOTA DC   1570198500000  4.654296 -74.055749   2001162.0
# 3           SUBA  BOGOTA DC   1486566000000  4.709924 -74.079962  11010306.0
# 4        KENNEDY  BOGOTA DC   1496184600000  4.618101 -74.168603   8007308.0
#
#    PK_CALZADA
# 0    514011.0
# 1    513766.0
# 2     36812.0
# 3    604024.0
# 4    245247.0

# %% [markdown]
# Información del archivo
#
# El DataFrame tiene 165.830 filas y 19 columnas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165830 entries, 0 to 165829
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    165830 non-null  int64
#  1   OBJECTID              165830 non-null  int64
#  2   FORMULARIO            165830 non-null  object
#  3   CODIGO_ACCIDENTE      165830 non-null  float64
#  4   FECHA_OCURRENCIA_ACC  165830 non-null  int64
#  5   HORA_OCURRENCIA_ACC   165830 non-null  object
#  6   ANO_OCURRENCIA_ACC    165830 non-null  float64
#  7   MES_OCURRENCIA_ACC    165830 non-null  object
#  8   DIA_OCURRENCIA_ACC    165830 non-null  object
#  9   DIRECCION             165830 non-null  object
#  10  GRAVEDAD              165830 non-null  object
#  11  CLASE_ACC             165830 non-null  object
#  12  LOCALIDAD             165830 non-null  object
#  13  MUNICIPIO             165830 non-null  object
#  14  FECHA_HORA_ACC        165830 non-null  int64
#  15  LATITUD               165830 non-null  float64
#  16  LONGITUD              165830 non-null  float64
#  17  CIV                   165427 non-null  float64
#  18  PK_CALZADA            165226 non-null  float64
# dtypes: float64(6), int64(4), object(9)
# memory usage: 24.0+ MB

# %% [markdown]
# ## 1. Variables categóricas por tipo de dato

# %% [markdown]
# Variables categóricas encontradas

# %%
non_numeric_attributes = df.select_dtypes(exclude=['number']).columns.values
pd.DataFrame(non_numeric_attributes, columns=['Non Numeric Attributes'])
# Out:
#   Non Numeric Attributes
# 0             FORMULARIO
# 1    HORA_OCURRENCIA_ACC
# 2     MES_OCURRENCIA_ACC
# 3     DIA_OCURRENCIA_ACC
# 4              DIRECCION
# 5               GRAVEDAD
# 6              CLASE_ACC
# 7              LOCALIDAD
# 8              MUNICIPIO

# %% [markdown]
# Conteo de filas, cantidad de filas únicas, moda y su frecuencia

# %%
df[non_numeric_attributes].describe()
# Out:
#         FORMULARIO HORA_OCURRENCIA_ACC MES_OCURRENCIA_ACC DIA_OCURRENCIA_ACC  \
# count       165830              165830             165830             165830
# unique      165830                1440                 12                  7
# top     A000758580            14:00:00              MARZO            VIERNES
# freq             1                1797              15073              26811
#
#             DIRECCION    GRAVEDAD CLASE_ACC LOCALIDAD  MUNICIPIO
# count          165830      165830    165830    165830     165830
# unique          75313           3         7        20          1
# top     KR 80-CL 2 51  SOLO DANOS    CHOQUE   KENNEDY  BOGOTA DC
# freq              168       94228    139853     20151     165830

# %% [markdown]
# **Hallazgos:**
#
# - No hay valores nulos
# - El formulario es único en el dataset
# - Se tienen 1440 horas de ocurrencia, es decir, exactamente todas las combinaciones de horas militares y minutos
# - La hora de ocurrencia más común es las 2 de la tarde
# - Se tienen todos los meses del año
# - El mes de ocurrencia más común es marzo
# - Se tienen todos los días de la semana
# - El día de ocurrencia más común es el viernes
# - Hay 3 tipos de gravedades
# - La gravedad más común es 'solo daños'
# - Hay 7 tipos de clases de accidentes
# - El tipo de accidente más común es 'choque'
# - Se tienen todas las 20 localidades de Bogotá
# - La localidad más común es Kennedy
# - El municipio siempre es Bogotá, como es esperado

# %% [markdown]
# Conteos y porcentajes para cada valor único en las columnas

# %%
for col in non_numeric_attributes:
    print(col)
    attribute = df[col].value_counts()
    df_attribute = pd.DataFrame({
        f"{col} values": attribute.index,
        "Count": attribute.values,
        "Percentage (%)": attribute.values * 100 / attribute.values.sum()
    }).sort_values(by="Count", ascending=False)

    print(f"\n--- TOP 10 ---")
    print_table(df_attribute.head(10))

    if len(df_attribute) > 10:
        print(f"\n--- BOTTOM 10 ---")
        print_table(df_attribute.tail(10))
# Out:
# FORMULARIO
#
# --- TOP 10 ---
# ┌────────┬─────────────────────┬─────────┬──────────────────┐
# │        │ FORMULARIO values   │   Count │   Percentage (%) │
# ├────────┼─────────────────────┼─────────┼──────────────────┤
# │ 165829 │ AA000910168         │       1 │      0.000603027 │
# │      0 │ A000758580          │       1 │      0.000603027 │
# │      1 │ A001393604          │       1 │      0.000603027 │
# │      2 │ AA001057402         │       1 │      0.000603027 │
# │      3 │ A001055948          │       1 │      0.000603027 │
# │      4 │ AA000552205         │       1 │      0.000603027 │
# │ 165813 │ A001512167          │       1 │      0.000603027 │
# │ 165812 │ AA000964793         │       1 │      0.000603027 │
# │ 165811 │ AA000554190         │       1 │      0.000603027 │
# │ 165810 │ A001567236          │       1 │      0.000603027 │
# └────────┴─────────────────────┴─────────┴──────────────────┘
#
# --- BOTTOM 10 ---
# ┌────┬─────────────────────┬─────────┬──────────────────┐
# │    │ FORMULARIO values   │   Count │   Percentage (%) │
# ├────┼─────────────────────┼─────────┼──────────────────┤
# │ 15 │ A001394875          │       1 │      0.000603027 │
# │ 14 │ AA001233132         │       1 │      0.000603027 │
# │ 13 │ A001609514          │       1 │      0.000603027 │
# │ 12 │ AA000969708         │       1 │      0.000603027 │
# │ 11 │ A000873426          │       1 │      0.000603027 │
# │ 10 │ A001393947          │       1 │      0.000603027 │
# │  9 │ A001610817          │       1 │      0.000603027 │
# │  8 │ A000969763          │       1 │      0.000603027 │
# │  7 │ AA000598928         │       1 │      0.000603027 │
# │  6 │ AA000763041         │       1 │      0.000603027 │
# └────┴─────────────────────┴─────────┴──────────────────┘
# HORA_OCURRENCIA_ACC
#
# --- TOP 10 ---
# ┌────┬──────────────────────────────┬─────────┬──────────────────┐
# │    │ HORA_OCURRENCIA_ACC values   │   Count │   Percentage (%) │
# ├────┼──────────────────────────────┼─────────┼──────────────────┤
# │  0 │ 14:00:00                     │    1797 │         1.08364  │
# │  1 │ 13:00:00                     │    1709 │         1.03057  │
# │  2 │ 12:30:00                     │    1707 │         1.02937  │
# │  3 │ 15:00:00                     │    1691 │         1.01972  │
# │  4 │ 11:00:00                     │    1615 │         0.973889 │
# │  5 │ 16:00:00                     │    1606 │         0.968462 │
# │  6 │ 13:30:00                     │    1605 │         0.967859 │
# │  7 │ 14:30:00                     │    1598 │         0.963637 │
# │  8 │ 08:00:00                     │    1586 │         0.956401 │
# │  9 │ 15:30:00                     │    1575 │         0.949768 │
# └────┴──────────────────────────────┴─────────┴──────────────────┘
#
# --- BOTTOM 10 ---
# ┌──────┬──────────────────────────────┬─────────┬──────────────────┐
# │      │ HORA_OCURRENCIA_ACC values   │   Count │   Percentage (%) │
# ├──────┼──────────────────────────────┼─────────┼──────────────────┤
# │ 1430 │ 04:29:00                     │       3 │       0.00180908 │
# │ 1425 │ 04:01:00                     │       3 │       0.00180908 │
# │ 1436 │ 04:54:00                     │       2 │       0.00120605 │
# │ 1435 │ 03:52:00                     │       2 │       0.00120605 │
# │ 1434 │ 04:02:00                     │       2 │       0.00120605 │
# │ 1433 │ 02:51:00                     │       2 │       0.00120605 │
# │ 1432 │ 03:17:00                     │       2 │       0.00120605 │
# │ 1439 │ 02:38:00                     │       2 │       0.00120605 │
# │ 1437 │ 02:31:00                     │       2 │       0.00120605 │
# │ 1438 │ 02:03:00                     │       2 │       0.00120605 │
# └──────┴──────────────────────────────┴─────────┴──────────────────┘
# MES_OCURRENCIA_ACC
#
# --- TOP 10 ---
# ┌────┬─────────────────────────────┬─────────┬──────────────────┐
# │    │ MES_OCURRENCIA_ACC values   │   Count │   Percentage (%) │
# ├────┼─────────────────────────────┼─────────┼──────────────────┤
# │  0 │ MARZO                       │   15073 │          9.08943 │
# │  1 │ FEBRERO                     │   14639 │          8.82772 │
# │  2 │ AGOSTO                      │   14217 │          8.57324 │
# │  3 │ MAYO                        │   14163 │          8.54067 │
# │  4 │ OCTUBRE                     │   14127 │          8.51897 │
# │  5 │ DICIEMBRE                   │   13974 │          8.4267  │
# │  6 │ SEPTIEMBRE                  │   13944 │          8.40861 │
# │  7 │ NOVIEMBRE                   │   13837 │          8.34409 │
# │  8 │ JULIO                       │   13763 │          8.29946 │
# │  9 │ JUNIO                       │   13378 │          8.0673  │
# └────┴─────────────────────────────┴─────────┴──────────────────┘
#
# --- BOTTOM 10 ---
# ┌────┬─────────────────────────────┬─────────┬──────────────────┐
# │    │ MES_OCURRENCIA_ACC values   │   Count │   Percentage (%) │
# ├────┼─────────────────────────────┼─────────┼──────────────────┤
# │  2 │ AGOSTO                      │   14217 │          8.57324 │
# │  3 │ MAYO                        │   14163 │          8.54067 │
# │  4 │ OCTUBRE                     │   14127 │          8.51897 │
# │  5 │ DICIEMBRE                   │   13974 │          8.4267  │
# │  6 │ SEPTIEMBRE                  │   13944 │          8.40861 │
# │  7 │ NOVIEMBRE                   │   13837 │          8.34409 │
# │  8 │ JULIO                       │   13763 │          8.29946 │
# │  9 │ JUNIO                       │   13378 │          8.0673  │
# │ 10 │ ABRIL                       │   12444 │          7.50407 │
# │ 11 │ ENERO                       │   12271 │          7.39975 │
# └────┴─────────────────────────────┴─────────┴──────────────────┘
# DIA_OCURRENCIA_ACC
#
# --- TOP 10 ---
# ┌────┬─────────────────────────────┬─────────┬──────────────────┐
# │    │ DIA_OCURRENCIA_ACC values   │   Count │   Percentage (%) │
# ├────┼─────────────────────────────┼─────────┼──────────────────┤
# │  0 │ VIERNES                     │   26811 │          16.1678 │
# │  1 │ SABADO                      │   25467 │          15.3573 │
# │  2 │ MARTES                      │   25445 │          15.344  │
# │  3 │ MIERCOLES                   │   24518 │          14.785  │
# │  4 │ JUEVES                      │   24253 │          14.6252 │
# │  5 │ LUNES                       │   22270 │          13.4294 │
# │  6 │ DOMINGO                     │   17066 │          10.2913 │
# └────┴─────────────────────────────┴─────────┴──────────────────┘
# DIRECCION
#
# --- TOP 10 ---
# ┌────┬─────────────────────────────────────┬─────────┬──────────────────┐
# │    │ DIRECCION values                    │   Count │   Percentage (%) │
# ├────┼─────────────────────────────────────┼─────────┼──────────────────┤
# │  0 │ KR 80-CL 2 51                       │     168 │        0.101309  │
# │  1 │ CL 13-KR 72 02                      │     105 │        0.0633179 │
# │  2 │ AV AVENIDA DE LAS AMERICAS-KR 72 02 │      85 │        0.0512573 │
# │  3 │ CL 13-KR 72 2                       │      81 │        0.0488452 │
# │  4 │ CL 80-KR 72 2                       │      77 │        0.0464331 │
# │  5 │ AV AVENIDA DE LAS AMERICAS-KR 68 02 │      77 │        0.0464331 │
# │  6 │ AV AVENIDA BOYACA-CL 26 02          │      74 │        0.044624  │
# │  8 │ AV AVENIDA BOYACA-CL 80 02          │      73 │        0.044021  │
# │  7 │ KR 50-CL 3 02                       │      73 │        0.044021  │
# │  9 │ CL 80-KR 72 02                      │      71 │        0.0428149 │
# └────┴─────────────────────────────────────┴─────────┴──────────────────┘
#
# --- BOTTOM 10 ---
# ┌───────┬─────────────────────────────────────┬─────────┬──────────────────┐
# │       │ DIRECCION values                    │   Count │   Percentage (%) │
# ├───────┼─────────────────────────────────────┼─────────┼──────────────────┤
# │ 32794 │ KR 19-CL 160 02                     │       1 │      0.000603027 │
# │ 32793 │ AV AVENIDA DE LAS AMERICAS-KR 63 05 │       1 │      0.000603027 │
# │ 32792 │ KR 58-CL 14 2                       │       1 │      0.000603027 │
# │ 32791 │ KR 79F-CL 47B S 02                  │       1 │      0.000603027 │
# │ 32790 │ CL 59C-KR 49 S 29                   │       1 │      0.000603027 │
# │ 32789 │ AV AVENIDA CARACAS-CL 54 73         │       1 │      0.000603027 │
# │ 75311 │ CL 16 SUR 52 02                     │       1 │      0.000603027 │
# │ 75310 │ KR 5 26 02                          │       1 │      0.000603027 │
# │ 75309 │ CL 11-KR 0 SE 02                    │       1 │      0.000603027 │
# │ 75308 │ KR 80-CL 40C S 06                   │       1 │      0.000603027 │
# └───────┴─────────────────────────────────────┴─────────┴──────────────────┘
# GRAVEDAD
#
# --- TOP 10 ---
# ┌────┬───────────────────┬─────────┬──────────────────┐
# │    │ GRAVEDAD values   │   Count │   Percentage (%) │
# ├────┼───────────────────┼─────────┼──────────────────┤
# │  0 │ SOLO DANOS        │   94228 │          56.822  │
# │  1 │ CON HERIDOS       │   68464 │          41.2857 │
# │  2 │ CON MUERTOS       │    3138 │           1.8923 │
# └────┴───────────────────┴─────────┴──────────────────┘
# CLASE_ACC
#
# --- TOP 10 ---
# ┌────┬────────────────────┬─────────┬──────────────────┐
# │    │ CLASE_ACC values   │   Count │   Percentage (%) │
# ├────┼────────────────────┼─────────┼──────────────────┤
# │  0 │ CHOQUE             │  139853 │      84.3352     │
# │  1 │ ATROPELLO          │   17996 │      10.8521     │
# │  2 │ CAIDA DE OCUPANTE  │    4327 │       2.6093     │
# │  3 │ VOLCAMIENTO        │    2772 │       1.67159    │
# │  4 │ OTRO               │     851 │       0.513176   │
# │  5 │ INCENDIO           │      28 │       0.0168848  │
# │  6 │ AUTOLESION         │       3 │       0.00180908 │
# └────┴────────────────────┴─────────┴──────────────────┘
# LOCALIDAD
#
# --- TOP 10 ---
# ┌────┬────────────────────┬─────────┬──────────────────┐
# │    │ LOCALIDAD values   │   Count │   Percentage (%) │
# ├────┼────────────────────┼─────────┼──────────────────┤
# │  0 │ KENNEDY            │   20151 │         12.1516  │
# │  1 │ ENGATIVA           │   16787 │         10.123   │
# │  2 │ USAQUEN            │   14966 │          9.02491 │
# │  3 │ SUBA               │   14900 │          8.98511 │
# │  4 │ FONTIBON           │   13710 │          8.2675  │
# │  5 │ PUENTE ARANDA      │   11862 │          7.15311 │
# │  6 │ BARRIOS UNIDOS     │    8497 │          5.12392 │
# │  7 │ TEUSAQUILLO        │    8455 │          5.09859 │
# │  8 │ CHAPINERO          │    8406 │          5.06905 │
# │  9 │ BOSA               │    8195 │          4.94181 │
# └────┴────────────────────┴─────────┴──────────────────┘
#
# --- BOTTOM 10 ---
# ┌────┬────────────────────┬─────────┬──────────────────┐
# │    │ LOCALIDAD values   │   Count │   Percentage (%) │
# ├────┼────────────────────┼─────────┼──────────────────┤
# │ 10 │ CIUDAD BOLIVAR     │    7354 │       4.43466    │
# │ 11 │ LOS MARTIRES       │    5222 │       3.14901    │
# │ 12 │ TUNJUELITO         │    5037 │       3.03745    │
# │ 13 │ RAFAEL URIBE URIBE │    4713 │       2.84207    │
# │ 14 │ SAN CRISTOBAL      │    4564 │       2.75222    │
# │ 15 │ SANTA FE           │    4454 │       2.68588    │
# │ 16 │ ANTONIO NARINO     │    3793 │       2.28728    │
# │ 17 │ USME               │    3715 │       2.24025    │
# │ 18 │ CANDELARIA         │    1044 │       0.62956    │
# │ 19 │ SUMAPAZ            │       5 │       0.00301514 │
# └────┴────────────────────┴─────────┴──────────────────┘
# MUNICIPIO
#
# --- TOP 10 ---
# ┌────┬────────────────────┬─────────┬──────────────────┐
# │    │ MUNICIPIO values   │   Count │   Percentage (%) │
# ├────┼────────────────────┼─────────┼──────────────────┤
# │  0 │ BOGOTA DC          │  165830 │              100 │
# └────┴────────────────────┴─────────┴──────────────────┘

# %% [markdown]
# **Hallazgos:**
#
# - No hay cadenas de texto vacías
# - Los valores están en mayúsculas y sin tildes
# - No se evidencian problemas con los valores únicos

# %% [markdown]
# Exclusión de variables a analizar

# %%
analyzed_non_numeric_attributes = [col for col in non_numeric_attributes if col != 'FORMULARIO' and col != 'DIRECCION' and col != 'HORA_OCURRENCIA_ACC' and col != 'MUNICIPIO']

# %% [markdown]
# Visualización de esta información con diagramas de barras (conteos)

# %%
for col in analyzed_non_numeric_attributes:
    plt.figure(figsize=(5, 4))
    ax = sns.countplot(data=df, x=col)
    for label in ax.get_xticklabels():
        label.set_rotation(90)
    plt.title(f"Countplot para {col}")

    plt.show()

# %% [markdown]
# ## 2. Variables numéricas por tipo de dato

# %% [markdown]
# Variables numéricas encontradas

# %%
numeric_attributes = df.select_dtypes(include=['number']).columns.values
pd.DataFrame(numeric_attributes, columns=['Numeric Attributes'])
# Out:
#      Numeric Attributes
# 0                    ID
# 1              OBJECTID
# 2      CODIGO_ACCIDENTE
# 3  FECHA_OCURRENCIA_ACC
# 4    ANO_OCURRENCIA_ACC
# 5        FECHA_HORA_ACC
# 6               LATITUD
# 7              LONGITUD
# 8                   CIV
# 9            PK_CALZADA

# %% [markdown]
# Conteo de filas, promedio, desviación estándar, valores mínimo y máximo junto a los cuartiles

# %%
df[numeric_attributes].describe()
# Out:
#                   ID       OBJECTID  CODIGO_ACCIDENTE  FECHA_OCURRENCIA_ACC  \
# count  165830.000000  165830.000000      1.658300e+05          1.658300e+05
# mean   729878.822867  492365.225870      9.942467e+06          1.577073e+12
# std     95691.949287  144218.433336      2.124264e+06          6.743525e+10
# min    563210.000000  279824.000000      4.469074e+06          1.483247e+12
# 25%    647005.250000  366649.500000      1.049138e+07          1.523596e+12
# 50%    729776.000000  456043.000000      1.057742e+07          1.563340e+12
# 75%    812743.250000  632645.750000      1.101445e+07          1.619154e+12
# max    895659.000000  892382.000000      1.133528e+07          1.757048e+12
#
#        ANO_OCURRENCIA_ACC  FECHA_HORA_ACC        LATITUD       LONGITUD  \
# count       165830.000000    1.658300e+05  165830.000000  165830.000000
# mean          2019.474166    1.577121e+12       4.646771     -74.105771
# std              2.132961    6.743532e+10       0.057964       0.040120
# min           2017.000000    1.483250e+12       4.122000     -74.237218
# 25%           2018.000000    1.523622e+12       4.605619     -74.135855
# 50%           2019.000000    1.563389e+12       4.641638     -74.104700
# 75%           2021.000000    1.619210e+12       4.688594     -74.075136
# max           2025.000000    1.757096e+12       4.825000     -74.010747
#
#                 CIV    PK_CALZADA
# count  1.654270e+05  1.652260e+05
# mean   1.163739e+07  1.747869e+07
# std    1.181077e+07  3.282184e+07
# min    0.000000e+00  0.000000e+00
# 25%    6.002058e+06  1.746820e+05
# 50%    1.000336e+07  3.881400e+05
# 75%    1.300293e+07  2.411993e+07
# max    1.001191e+08  9.106576e+07

# %% [markdown]
# Valores únicos en cada columna

# %%
unique_counts = df[numeric_attributes].nunique()
print(unique_counts)
# Out:
# ID                      165830
# OBJECTID                165830
# CODIGO_ACCIDENTE        165830
# FECHA_OCURRENCIA_ACC      3166
# ANO_OCURRENCIA_ACC           9
# FECHA_HORA_ACC          120976
# LATITUD                  85919
# LONGITUD                 85085
# CIV                      36548
# PK_CALZADA               44971
# dtype: int64

# %% [markdown]
# **Hallazgos y notas:**
#
# - Las columnas CIV y PK_CALZADA tienen valores nulos
# - ID, OBJECTID, CODIGO_ACCIDENTE y FECHA_HORA_ACC tienen una alta cardinalidad
# - Las fechas (FECHA_OCURRENCIA_ACC Y FECHA_HORA_ACC) están en un timestamp Unix de milisegundos, dado que las fechas recientes (2019 - 2022) están cerca de 1.6 × 10¹²
# - Los años van correctamente desde 2017 hasta 2025
# - La latitud y longitud es coherente
# - CIV hace referencia al Código de Identificación Vial (CIV), lo que permite consultar segmentos viales
# - Un segmento vial es un tramo continuo de una vía entre dos intersecciones consecutivas o entre dos puntos de quiebre definidos oficialmente
# - PK_CALZADA hace referencia al código de la calzada
# - Una calzada es una zona de la vía, destinada a la circulación de vehículos automotores o peatones (IDECA, 2021)
# - Hay cerca de 36k segmentos viales y 44k calzadas
#
# **Conversiones adecuadas:**
#
# - De float a int:
#     - CODIGO_ACCIDENTE
#     - ANO_OCURRENCIA_ACC
#     - CIV
#     - PK_CALZADA
# - De int a fecha en UTC−05:00:
#     - FECHA_OCURRENCIA_ACC
#     - FECHA_HORA_ACC
#
# **Referencias:**
#
# IDECA (Infraestructura de Datos Espaciales de Bogotá). (31 de marzo de 2021). Calzada. Bogotá D.C. https://www.ideca.gov.co/recursos/mapas/calzada-bogota-dc

# %% [markdown]
# Visualización de esta información con diagramas de caja

# %%
for c in numeric_attributes:
    plt.figure(figsize=(5, 4))          # tamaño de cada figura
    sns.boxplot(y=df[c])                # eje Y = columna
    plt.title(f"Boxplot de {c}")        # título
    plt.xlabel("")                      # sin etiqueta en X (opcional)
    plt.ylabel(c)                       # nombre de la variable
    plt.show()

# %% [markdown]
# **Hallazgos:**
#
# - Los códigos de accidente inferiores (de 6 dígitos) son outliers o errores
# - Los demás outliers son razonables

# %% [markdown]
# Histogramas para visualizar la distribución de cada columna

# %%
for col in numeric_attributes:
    plt.figure(figsize=(5,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Histograma con línea de tendencia para {col}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Hallazgos:**
#
# - Ha disminuido notoriamente la cantidad de siniestros desde 2017 hasta 2025
# - Son más comunes los siniestros registrados en segmentos viales con CIVs bajos
# - Hay 5 rangos de identificadores de calzadas que concentran una cantidad importante de los siniestros, lo que resaltaría ciertas divisiones territoriales

# %% [markdown]
# ## 3. Calidad de datos

# %% [markdown]
# ### 3.1. Completitud
#
# **Diagnóstico:** Se encontraron problemas menores

# %% [markdown]
# Valores de incompletitud para todas las columnas

# %%
incompleteness_percentages =  (100 * df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
pd.DataFrame({
    "Attribute": incompleteness_percentages.index,
    "Completeness (%)": 100 - incompleteness_percentages.values
})
# Out:
#                Attribute  Completeness (%)
# 0             PK_CALZADA         99.635772
# 1                    CIV         99.756980
# 2                     ID        100.000000
# 3             FORMULARIO        100.000000
# 4               OBJECTID        100.000000
# 5       CODIGO_ACCIDENTE        100.000000
# 6   FECHA_OCURRENCIA_ACC        100.000000
# 7     MES_OCURRENCIA_ACC        100.000000
# 8     DIA_OCURRENCIA_ACC        100.000000
# 9    HORA_OCURRENCIA_ACC        100.000000
# 10    ANO_OCURRENCIA_ACC        100.000000
# 11              GRAVEDAD        100.000000
# 12             DIRECCION        100.000000
# 13             CLASE_ACC        100.000000
# 14             LOCALIDAD        100.000000
# 15        FECHA_HORA_ACC        100.000000
# 16             MUNICIPIO        100.000000
# 17              LONGITUD        100.000000
# 18               LATITUD        100.000000

# %% [markdown]
# Evidenciamos que menos de un 1% de los valores de CIV y PK_CALZADA son nulos
#
# Podemos utilizar el placeholder de 0 para indicar esto y poder realizar conversiones de tipos de dato. Además, en el dataset original este valor ya estaba incluido en su rango, por lo que es un buen placeholder.

# %%
df = df.fillna(0)

# %% [markdown]
# Corrección exitosa

# %%
incompleteness_percentages =  (100 * df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
pd.DataFrame({
    "Attribute": incompleteness_percentages.index,
    "Completeness (%)": 100 - incompleteness_percentages.values
})
# Out:
#                Attribute  Completeness (%)
# 0                     ID             100.0
# 1               OBJECTID             100.0
# 2             FORMULARIO             100.0
# 3       CODIGO_ACCIDENTE             100.0
# 4   FECHA_OCURRENCIA_ACC             100.0
# 5    HORA_OCURRENCIA_ACC             100.0
# 6     ANO_OCURRENCIA_ACC             100.0
# 7     MES_OCURRENCIA_ACC             100.0
# 8     DIA_OCURRENCIA_ACC             100.0
# 9              DIRECCION             100.0
# 10              GRAVEDAD             100.0
# 11             CLASE_ACC             100.0
# 12             LOCALIDAD             100.0
# 13             MUNICIPIO             100.0
# 14        FECHA_HORA_ACC             100.0
# 15               LATITUD             100.0
# 16              LONGITUD             100.0
# 17                   CIV             100.0
# 18            PK_CALZADA             100.0

# %% [markdown]
# ### 3.2. Unicidad
#
# **Diagnóstico:** No se encontraron problemas

# %% [markdown]
# Cantidad de filas duplicadas

# %%
total_duplicate_rows = df.duplicated().sum()
duplicate_rows_percentage = 100.0 * total_duplicate_rows / df.shape[0]
print(f"{total_duplicate_rows} duplicate rows ({duplicate_rows_percentage:.2f}%)")
# Out:
# 0 duplicate rows (0.00%)

# %% [markdown]
# Cantidad de valores duplicados por cada columna

# %%
duplicate_counts = []
duplicate_percentages = []

for col in df.columns:
    duplicates = df.shape[0] - df[col].nunique()
    duplicate_counts.append(duplicates)
    duplicate_percentages.append((duplicates / df.shape[0]) * 100)

duplicates_df = pd.DataFrame({
    "Column": df.columns,
    "Duplicate Count": duplicate_counts,
    "Duplicate Percentage": duplicate_percentages
}).sort_values(by="Duplicate Count", ascending=False).reset_index(drop=True)

duplicates_df
# Out:
#                   Column  Duplicate Count  Duplicate Percentage
# 0              MUNICIPIO           165829             99.999397
# 1               GRAVEDAD           165827             99.998191
# 2              CLASE_ACC           165823             99.995779
# 3     DIA_OCURRENCIA_ACC           165823             99.995779
# 4     ANO_OCURRENCIA_ACC           165821             99.994573
# 5     MES_OCURRENCIA_ACC           165818             99.992764
# 6              LOCALIDAD           165810             99.987939
# 7    HORA_OCURRENCIA_ACC           164390             99.131641
# 8   FECHA_OCURRENCIA_ACC           162664             98.090816
# 9                    CIV           129282             77.960562
# 10            PK_CALZADA           120859             72.881264
# 11             DIRECCION            90517             54.584213
# 12              LONGITUD            80745             48.691431
# 13               LATITUD            79911             48.188506
# 14        FECHA_HORA_ACC            44854             27.048182
# 15            FORMULARIO                0              0.000000
# 16              OBJECTID                0              0.000000
# 17                    ID                0              0.000000
# 18      CODIGO_ACCIDENTE                0              0.000000

# %% [markdown]
# ## 4. Conversiones de columnas

# %% [markdown]
# Convertimos las columnas de float a int

# %%
cols = ["CODIGO_ACCIDENTE", "ANO_OCURRENCIA_ACC", "CIV", "PK_CALZADA"]
df = df.astype({c: "int" for c in cols})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165830 entries, 0 to 165829
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    165830 non-null  int64
#  1   OBJECTID              165830 non-null  int64
#  2   FORMULARIO            165830 non-null  object
#  3   CODIGO_ACCIDENTE      165830 non-null  int64
#  4   FECHA_OCURRENCIA_ACC  165830 non-null  int64
#  5   HORA_OCURRENCIA_ACC   165830 non-null  object
#  6   ANO_OCURRENCIA_ACC    165830 non-null  int64
#  7   MES_OCURRENCIA_ACC    165830 non-null  object
#  8   DIA_OCURRENCIA_ACC    165830 non-null  object
#  9   DIRECCION             165830 non-null  object
#  10  GRAVEDAD              165830 non-null  object
#  11  CLASE_ACC             165830 non-null  object
#  12  LOCALIDAD             165830 non-null  object
#  13  MUNICIPIO             165830 non-null  object
#  14  FECHA_HORA_ACC        165830 non-null  int64
#  15  LATITUD               165830 non-null  float64
#  16  LONGITUD              165830 non-null  float64
#  17  CIV                   165830 non-null  int64
#  18  PK_CALZADA            165830 non-null  int64
# dtypes: float64(2), int64(8), object(9)
# memory usage: 24.0+ MB

# %% [markdown]
# Guardamos las fechas convertidas en otras columnas

# %%
df["FECHA_OCURRENCIA_ACC"] = (
    pd.to_datetime(df["FECHA_OCURRENCIA_ACC"], unit="ms", origin="unix")
      .dt.tz_localize("UTC")
      .dt.tz_convert("America/Bogota")
      .dt.date
)

df["FECHA_OCURRENCIA_ACC"].head()
# Out:
# 0    2022-03-16
# 1    2019-10-18
# 2    2019-10-04
# 3    2017-02-08
# 4    2017-05-30
# Name: FECHA_OCURRENCIA_ACC, dtype: object

# %%
df["FECHA_HORA_ACC"] = (
    pd.to_datetime(df["FECHA_HORA_ACC"], unit="ms", origin="unix")
      .dt.tz_localize("UTC")
      .dt.tz_convert("America/Bogota")
      .dt.strftime("%Y-%m-%d %H:%M")
)

df["FECHA_HORA_ACC"].head()
# Out:
# 0    2022-03-16 06:34
# 1    2019-10-18 19:30
# 2    2019-10-04 09:15
# 3    2017-02-08 10:00
# 4    2017-05-30 17:50
# Name: FECHA_HORA_ACC, dtype: object

# %% [markdown]
# Finalmente, como las horas no guardan segundos, podemos estandarizar:

# %%
df["HORA_OCURRENCIA_ACC"].str.endswith(":00").all()
# Out:
# np.True_

# %%
df["HORA_OCURRENCIA_ACC"] = df["HORA_OCURRENCIA_ACC"].str.replace(r":00$", "", regex=True)
df["HORA_OCURRENCIA_ACC"].head()
# Out:
# 0    06:34
# 1    19:30
# 2    09:15
# 3    10:00
# 4    17:50
# Name: HORA_OCURRENCIA_ACC, dtype: object

# %% [markdown]
# ## 5. Sampling para visualización

# %% [markdown]
# Resultado de las transformaciones

# %%
df.head()
# Out:
#        ID  OBJECTID   FORMULARIO  CODIGO_ACCIDENTE FECHA_OCURRENCIA_ACC  \
# 0  840142    451106   A001393604          10565887           2022-03-16
# 1  747565    728008  AA001057402          11115230           2019-10-18
# 2  744198    372498   A001055948          10499024           2019-10-04
# 3  570467    631431  AA000552205          11001813           2017-02-08
# 4  590737    303501   A000607860           4483415           2017-05-30
#
#   HORA_OCURRENCIA_ACC  ANO_OCURRENCIA_ACC MES_OCURRENCIA_ACC  \
# 0               06:34                2022              MARZO
# 1               19:30                2019            OCTUBRE
# 2               09:15                2019            OCTUBRE
# 3               10:00                2017            FEBRERO
# 4               17:50                2017               MAYO
#
#   DIA_OCURRENCIA_ACC                    DIRECCION     GRAVEDAD  CLASE_ACC  \
# 0          MIERCOLES                  KR 86 72 02   SOLO DANOS     CHOQUE
# 1            VIERNES                 KR 50-CL 3 2  CON HERIDOS     CHOQUE
# 2            VIERNES                KR 7-CL 71 21   SOLO DANOS     CHOQUE
# 3          MIERCOLES  AV AVENIDA BOYACA-CL 127 02   SOLO DANOS     CHOQUE
# 4             MARTES           KR 79F-CL 47B S 02  CON HERIDOS  ATROPELLO
#
#        LOCALIDAD  MUNICIPIO    FECHA_HORA_ACC   LATITUD   LONGITUD       CIV  \
# 0       ENGATIVA  BOGOTA DC  2022-03-16 06:34  4.696000 -74.106000  10006480
# 1  PUENTE ARANDA  BOGOTA DC  2019-10-18 19:30  4.615541 -74.114489  16004606
# 2      CHAPINERO  BOGOTA DC  2019-10-04 09:15  4.654296 -74.055749   2001162
# 3           SUBA  BOGOTA DC  2017-02-08 10:00  4.709924 -74.079962  11010306
# 4        KENNEDY  BOGOTA DC  2017-05-30 17:50  4.618101 -74.168603   8007308
#
#    PK_CALZADA
# 0      514011
# 1      513766
# 2       36812
# 3      604024
# 4      245247

# %% [markdown]
# Guardar el dataset transformado

# %%
df.to_csv("datos_finales.csv", index=False, encoding="utf-8")

# %% [markdown]
# Guardar el dataset muestreado al 20%

# %%
muestra = df.sample(frac=0.2, random_state=42)
muestra.to_csv("datos_muestra.csv", index=False, encoding="utf-8")
